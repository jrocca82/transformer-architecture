# %%
import requests
from PIL import Image
from genaibook.core import SampleURL
from transformers import pipeline

# %%
url = SampleURL.CatExample
print(url)
image = Image.open(requests.get(url, stream=True).raw)
image
# Out:
# https://huggingface.co/datasets/huggingfacejs/tasks/resolve/main/zero-shot-image-classification/image-classification-input.jpeg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=937x704>

# %%
pipe = pipeline("zero-shot-image-classification", model="openai/clip-vit-base-patch32")
labels = ["cat", "dog", "zebra"]
result = pipe(image, candidate_labels=labels)
print(result)
# Out:
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Device set to use mps:0
# [{'score': 0.9936686158180237, 'label': 'cat'}, {'score': 0.00604326743632555, 'label': 'dog'}, {'score': 0.0002880467800423503, 'label': 'zebra'}]
